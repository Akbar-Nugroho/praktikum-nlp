# %%
# !pip install google-play-scraper
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.4-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.4

# %%
from google_play_scraper import Sort, reviews, app
import pandas as pd
import numpy as np

# %%
result, continuation_token = reviews(
    'com.HoYoverse.hkrpgoversea',
    lang='id',
    country='id',
    sort=Sort.MOST_RELEVANT,
    count=1000,
    filter_score_with=None
)

# %%
data = pd.DataFrame(np.array(result), columns=['review'])
data = data.join(pd.DataFrame(data.pop('review').tolist()))

# %%
data
# Out:
#                                  reviewId                   userName  \
# 0    6fb9f795-ba66-4377-a9dd-237b1fe82330                      mitha
# 1    e397ef50-d748-4206-b1cb-da49b77501a9                  Reo Senji
# 2    a09b0e7f-6386-4757-b6ad-3ed697fa5d66               Anwar Rosidi
# 3    71af2daa-c6a4-4d61-adab-1e45d8894e5d  Fabiel Syaindra Putradima
# 4    95743ea0-9946-4a40-8190-48aa9a28530e   Rafisal Gaming Indonesia
# ..                                    ...                        ...
# 995  465fe0ea-0a4d-45a1-bbab-03ce3c5def09       Anugrah Batara Mulya
# 996  5b6ad621-dbb8-479c-b6dd-ed37cd7ed3e3              Pieter Farhan
# 997  0831042a-84b7-407b-b28c-01a62511719a                   Faris RD
# 998  682de169-5f54-4ad9-be24-b51c9bf8f6fd            Rizki Dwi Bakti
# 999  775a2c4a-0425-4fb2-b4eb-6ff2e2d2287f            mandakafkabiyyu
#
#                                              userImage  \
# 0    https://play-lh.googleusercontent.com/a-/ALV-U...
# 1    https://play-lh.googleusercontent.com/a-/ALV-U...
# 2    https://play-lh.googleusercontent.com/a/ACg8oc...
# 3    https://play-lh.googleusercontent.com/a-/ALV-U...
# 4    https://play-lh.googleusercontent.com/a-/ALV-U...
# ..                                                 ...
# 995  https://play-lh.googleusercontent.com/a/ACg8oc...
# 996  https://play-lh.googleusercontent.com/a-/ALV-U...
# 997  https://play-lh.googleusercontent.com/a-/ALV-U...
# 998  https://play-lh.googleusercontent.com/a-/ALV-U...
# 999  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                                content  score  thumbsUpCount  \
# 0    game nya bagus bgtt, dari segi grafik, story, ...      5            543
# 1    Untuk player yang "loadingnya lama padahal sin...      5            184
# 2    Gamenya sangat bagus. sedikit masukan dari say...      4             61
# 3    Bagus game nya. Dari segi grafik, animasi, sto...      5             13
# 4    Capek banget untuk mendapatkan material untuk ...      1              5
# ..                                                 ...    ...            ...
# 995  kenapa akun saya hilang, setelah instal ulang ...      1              0
# 996  Overall bagus banget, storynya mudah dicerna d...      5              0
# 997  Overall gamenya bagus 👍, mulai dari kontrol, d...      5              0
# 998  Awalnya sih kurang suka sama ini game... Soaln...      5              0
# 999  Game ini sedang mengalami beberapa update bera...      3              0
#
#     reviewCreatedVersion                  at replyContent repliedAt appVersion
# 0                  1.3.0 2023-09-29 11:11:12         None      None      1.3.0
# 1                  1.3.0 2023-09-12 14:07:44         None      None      1.3.0
# 2                  1.3.0 2023-09-26 21:37:35         None      None      1.3.0
# 3                  1.3.0 2023-09-16 01:46:56         None      None      1.3.0
# 4                  1.3.0 2023-10-04 05:06:56         None      None      1.3.0
# ..                   ...                 ...          ...       ...        ...
# 995                1.3.0 2023-09-16 20:14:38         None      None      1.3.0
# 996                1.0.5 2023-05-29 14:39:09         None      None      1.0.5
# 997                1.0.5 2023-04-30 12:43:16         None      None      1.0.5
# 998                1.0.5 2023-06-02 14:36:00         None      None      1.0.5
# 999                1.0.5 2023-05-26 13:26:09         None      None      1.0.5
#
# [1000 rows x 11 columns]

# %%
data.to_csv('Honkai Star Rail.csv')
